# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns#Understanding my variables

# %% [markdown]
# **---------------------AUTO TEST STATS BELOW -------------------------------------**

# %%
auto_test_df = pd.read_csv('auto_test.txt', delimiter=',')

# %%
auto_test_df.head()
# Out:
#      id  auto_1_X  auto_1_Y  auto_2_X  auto_2_Y  auto_3_X  auto_3_Y  auto_4_X  \
# 0  2372     199.0     197.0     214.5     197.5     233.0     206.0     265.0
# 1  2367     232.0     189.0     258.5     183.5     287.0     193.0     328.0
# 2   433      72.0      87.0      82.0      83.0      92.0      86.0     112.0
# 3   426      90.0     102.0     106.0     102.0     120.0     105.0     139.0
# 4   982      67.0      79.0      79.0      78.0      89.0      81.0     104.0
#
#    auto_4_Y  auto_5_X  ...  auto_33_X  auto_33_Y  auto_34_X  auto_34_Y  \
# 0     213.0     290.5  ...      249.0      322.0      231.0      325.0
# 1     200.0     353.5  ...      328.0      322.0      318.0      326.0
# 2      84.0     124.0  ...      120.0      131.0      112.0      134.0
# 3     107.0     154.0  ...      140.0      157.0      133.0      163.0
# 4      83.0     114.0  ...      102.0      122.0       97.0      124.0
#
#    auto_35_X  auto_35_Y  auto_36_X  auto_36_Y  auto_37_X  auto_37_Y
# ...

# %%
auto_test_df.describe()
# Out:
#                 id     auto_1_X     auto_1_Y     auto_2_X     auto_2_Y  \
# count  3068.000000  3068.000000  3068.000000  3068.000000  3068.000000
# mean   1534.500000   174.245926   200.836897   197.709094   192.292568
# std     885.799639   129.947273   150.507815   148.620251   143.292749
# min       1.000000    14.000000    15.000000    15.600000    13.000000
# 25%     767.750000    67.000000    77.750000    76.000000    75.000000
# 50%    1534.500000   138.000000   156.000000   155.000000   150.500000
# 75%    2301.250000   249.250000   289.250000   284.125000   277.000000
# max    3068.000000   787.000000   945.900000   838.000000   909.400000
#
#           auto_3_X     auto_3_Y     auto_4_X     auto_4_Y     auto_5_X  ...  \
# count  3068.000000  3068.000000  3068.000000  3068.000000  3068.000000  ...
# mean    222.915450   197.639668   259.923468   197.039668   285.861180  ...
# std     168.822012   147.270675   198.142010   147.107879   218.922519  ...
# ...

# %%
auto_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3068 entries, 0 to 3067
# Data columns (total 75 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         3068 non-null   int64
#  1   auto_1_X   3068 non-null   float64
#  2   auto_1_Y   3068 non-null   float64
#  3   auto_2_X   3068 non-null   float64
#  4   auto_2_Y   3068 non-null   float64
#  5   auto_3_X   3068 non-null   float64
#  6   auto_3_Y   3068 non-null   float64
#  7   auto_4_X   3068 non-null   float64
#  8   auto_4_Y   3068 non-null   float64
#  9   auto_5_X   3068 non-null   float64
#  10  auto_5_Y   3068 non-null   float64
#  11  auto_6_X   3068 non-null   float64
#  12  auto_6_Y   3068 non-null   float64
#  13  auto_7_X   3068 non-null   float64
#  14  auto_7_Y   3068 non-null   float64
#  15  auto_8_X   3068 non-null   float64
#  16  auto_8_Y   3068 non-null   float64
#  17  auto_9_X   3068 non-null   float64
#  18  auto_9_Y   3068 non-null   float64
# ...

# %%
auto_test_df.isnull().values.any()
# Out:
# False

# %%
print(auto_test_df.shape)
# Out:
# (3068, 75)

# %%
print(auto_test_df.columns)
# Out:
# Index(['id', 'auto_1_X', 'auto_1_Y', 'auto_2_X', 'auto_2_Y', 'auto_3_X',
#        'auto_3_Y', 'auto_4_X', 'auto_4_Y', 'auto_5_X', 'auto_5_Y', 'auto_6_X',
#        'auto_6_Y', 'auto_7_X', 'auto_7_Y', 'auto_8_X', 'auto_8_Y', 'auto_9_X',
#        'auto_9_Y', 'auto_10_X', 'auto_10_Y', 'auto_11_X', 'auto_11_Y',
#        'auto_12_X', 'auto_12_Y', 'auto_13_X', 'auto_13_Y', 'auto_14_X',
#        'auto_14_Y', 'auto_15_X', 'auto_15_Y', 'auto_16_X', 'auto_16_Y',
#        'auto_17_X', 'auto_17_Y', 'auto_18_X', 'auto_18_Y', 'auto_19_X',
#        'auto_19_Y', 'auto_20_X', 'auto_20_Y', 'auto_21_X', 'auto_21_Y',
#        'auto_22_X', 'auto_22_Y', 'auto_23_X', 'auto_23_Y', 'auto_24_X',
#        'auto_24_Y', 'auto_25_X', 'auto_25_Y', 'auto_26_X', 'auto_26_Y',
#        'auto_27_X', 'auto_27_Y', 'auto_28_X', 'auto_28_Y', 'auto_29_X',
#        'auto_29_Y', 'auto_30_X', 'auto_30_Y', 'auto_31_X', 'auto_31_Y',
#        'auto_32_X', 'auto_32_Y', 'auto_33_X', 'auto_33_Y', 'auto_34_X',
# ...

# %%
auto_test_df.hist(column='auto_1_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd152e3110>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_1_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd12cc3410>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_2_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd15287050>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_2_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd12ce4910>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_3_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd12c58b50>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_3_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd138ea990>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_4_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13a2fcd0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_4_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13931410>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_5_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd12e383d0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_5_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13bc1e50>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_6_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13c0fa90>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_6_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13c7b490>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_7_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13d1fa50>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_7_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13005810>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_8_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13b23610>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_8_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd12dcdc90>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_9_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd12f17510>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_9_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd140f8b50>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_10_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14394710>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_10_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd137cd1d0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_11_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd1304bf90>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_11_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13fed190>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_12_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd1406ee50>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_12_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14141d90>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_13_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14132850>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_13_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14c7fa90>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_14_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14ef11d0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_14_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14447610>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_15_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd148fbed0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_15_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13f708d0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_16_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd146f1110>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_16_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13f63510>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_17_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14e352d0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_17_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd132d1290>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_18_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14b9bc90>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_18_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd144f6fd0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_19_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13c34490>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_19_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd131b9a90>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_20_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14b1ac50>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_20_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd1353d150>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_21_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd134e9150>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_21_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13306f90>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_22_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd143f2c90>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_22_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd1310f950>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_23_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14265090>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_23_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14778a10>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_24_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd1295a9d0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_24_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd15e2c610>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_25_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14d51390>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_25_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd137f7fd0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_26_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd15078990>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_26_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd15015150>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_27_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd135d7450>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_27_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14b40fd0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_28_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14809990>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_28_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14f9d2d0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_29_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14a5d990>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_29_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14cef890>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_30_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14d81bd0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_30_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14d898d0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_31_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd151c0910>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_31_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13109550>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_32_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd149b5910>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_32_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd136d9d10>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_33_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13655690>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_33_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd14661f10>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_34_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd128e92d0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_34_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd13830a50>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_35_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd12841590>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_35_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd127fac90>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_36_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd126a1590>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_36_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd126341d0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_37_X')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd125b65d0>]],
#       dtype=object)

# %%
auto_test_df.hist(column='auto_37_Y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd12544d10>]],
#       dtype=object)

# %% [markdown]
# -----------------**AUTO_TRAIN STATS BELOW**-----------------------------------

# %%
auto_train_df = pd.read_csv('auto_train.txt')

# %%
auto_train_df.head()
# Out:
#      id  auto_1_X  auto_1_Y  auto_2_X  auto_2_Y  auto_3_X  auto_3_Y  auto_4_X  \
# 0  8207     416.0     433.0     459.0     413.5     504.0     430.0     589.0
# 1  8212     356.0     511.0     453.0     477.0     540.0     509.0     640.0
# 2  2168     133.0     169.0     153.0     156.5     176.0     159.0     206.0
# 3  7952     145.0     167.0     156.5     164.0     168.0     167.0     186.0
# 4  7947      91.0     103.0     107.5     100.0     121.0     102.0     138.0
#
#    auto_4_Y  auto_5_X  ...  auto_33_X  auto_33_Y  auto_34_X  auto_34_Y  \
# 0     436.0     658.5  ...      586.0      703.0      540.0      719.0
# 1     516.0     704.0  ...      664.0      803.0      635.0      827.0
# 2     159.0     226.0  ...      222.0      234.0      214.0      239.0
# 3     176.0     200.0  ...      177.0      222.0      172.0      223.0
# 4     100.0     149.5  ...      137.0      159.0      133.0      162.0
#
#    auto_35_X  auto_35_Y  auto_36_X  auto_36_Y  auto_37_X  auto_37_Y
# ...

# %%
auto_train_df.describe()
# Out:
#                  id      auto_1_X      auto_1_Y      auto_2_X      auto_2_Y  \
# count  12271.000000  12271.000000  12271.000000  12271.000000  12271.000000
# mean    6136.000000    169.738750    195.341651    192.770695    187.185755
# std     3542.476911    126.907844    146.743158    145.022622    139.889962
# min        1.000000     15.000000      6.000000     16.200000     -1.000000
# 25%     3068.500000     68.500000     79.000000     77.500000     75.500000
# 50%     6136.000000    129.000000    148.000000    146.500000    142.000000
# 75%     9203.500000    244.000000    279.000000    276.500000    267.750000
# max    12271.000000   1080.500000   1067.400000   1052.900000   1054.900000
#
#            auto_3_X      auto_3_Y      auto_4_X      auto_4_Y      auto_5_X  \
# count  12271.000000  12271.000000  12271.000000  12271.000000  12271.000000
# mean     217.542637    192.457045    254.383041    191.936248    280.048399
# ...

# %%
auto_train_df.isnull().values.any()
# Out:
# False

# %%
auto_train_df.isnull().sum()
# Out:
# id           0
# auto_1_X     0
# auto_1_Y     0
# auto_2_X     0
# auto_2_Y     0
#             ..
# auto_35_Y    0
# auto_36_X    0
# auto_36_Y    0
# auto_37_X    0
# auto_37_Y    0
# Length: 75, dtype: int64

# %%
auto_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12271 entries, 0 to 12270
# Data columns (total 75 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         12271 non-null  int64
#  1   auto_1_X   12271 non-null  float64
#  2   auto_1_Y   12271 non-null  float64
#  3   auto_2_X   12271 non-null  float64
#  4   auto_2_Y   12271 non-null  float64
#  5   auto_3_X   12271 non-null  float64
#  6   auto_3_Y   12271 non-null  float64
#  7   auto_4_X   12271 non-null  float64
#  8   auto_4_Y   12271 non-null  float64
#  9   auto_5_X   12271 non-null  float64
#  10  auto_5_Y   12271 non-null  float64
#  11  auto_6_X   12271 non-null  float64
#  12  auto_6_Y   12271 non-null  float64
#  13  auto_7_X   12271 non-null  float64
#  14  auto_7_Y   12271 non-null  float64
#  15  auto_8_X   12271 non-null  float64
#  16  auto_8_Y   12271 non-null  float64
#  17  auto_9_X   12271 non-null  float64
#  18  auto_9_Y   12271 non-null  float64
# ...

# %%
auto_train_df.hist(column='auto_1_X')
auto_train_df.hist(column='auto_1_Y')
auto_train_df.hist(column='auto_2_X')
auto_train_df.hist(column='auto_2_Y')
auto_train_df.hist(column='auto_3_X')
auto_train_df.hist(column='auto_3_Y')
auto_train_df.hist(column='auto_4_X')
auto_train_df.hist(column='auto_4_Y')
auto_train_df.hist(column='auto_5_X')
auto_train_df.hist(column='auto_5_Y')
auto_train_df.hist(column='auto_6_X')
auto_train_df.hist(column='auto_6_Y')
auto_train_df.hist(column='auto_7_X')
auto_train_df.hist(column='auto_7_Y')
auto_train_df.hist(column='auto_8_X')
auto_train_df.hist(column='auto_8_Y')
auto_train_df.hist(column='auto_9_X')
auto_train_df.hist(column='auto_9_Y')
auto_train_df.hist(column='auto_10_X')
auto_train_df.hist(column='auto_10_Y')
auto_train_df.hist(column='auto_11_X')
auto_train_df.hist(column='auto_11_Y')
auto_train_df.hist(column='auto_12_X')
auto_train_df.hist(column='auto_12_Y')
auto_train_df.hist(column='auto_13_X')
auto_train_df.hist(column='auto_13_Y')
auto_train_df.hist(column='auto_14_X')
auto_train_df.hist(column='auto_14_Y')
auto_train_df.hist(column='auto_15_X')
auto_train_df.hist(column='auto_15_Y')
auto_train_df.hist(column='auto_16_X')
auto_train_df.hist(column='auto_16_Y')
auto_train_df.hist(column='auto_17_X')
auto_train_df.hist(column='auto_17_Y')
auto_train_df.hist(column='auto_18_X')
auto_train_df.hist(column='auto_18_Y')
auto_train_df.hist(column='auto_19_X')
auto_train_df.hist(column='auto_19_Y')
auto_train_df.hist(column='auto_20_X')
auto_train_df.hist(column='auto_20_Y')
auto_train_df.hist(column='auto_21_X')
auto_train_df.hist(column='auto_21_Y')
auto_train_df.hist(column='auto_22_X')
auto_train_df.hist(column='auto_22_Y')
auto_train_df.hist(column='auto_23_X')
auto_train_df.hist(column='auto_23_Y')
auto_train_df.hist(column='auto_24_X')
auto_train_df.hist(column='auto_24_Y')
auto_train_df.hist(column='auto_25_X')
auto_train_df.hist(column='auto_25_Y')
auto_train_df.hist(column='auto_26_X')
auto_train_df.hist(column='auto_26_Y')
auto_train_df.hist(column='auto_27_X')
auto_train_df.hist(column='auto_27_Y')
auto_train_df.hist(column='auto_28_X')
auto_train_df.hist(column='auto_28_Y')
auto_train_df.hist(column='auto_29_X')
auto_train_df.hist(column='auto_29_Y')
auto_train_df.hist(column='auto_30_X')
auto_train_df.hist(column='auto_30_Y')
auto_train_df.hist(column='auto_31_X')
auto_train_df.hist(column='auto_31_Y')
auto_train_df.hist(column='auto_32_X')
auto_train_df.hist(column='auto_33_X')
auto_train_df.hist(column='auto_33_Y')
auto_train_df.hist(column='auto_34_X')
auto_train_df.hist(column='auto_34_Y')
auto_train_df.hist(column='auto_35_X')
auto_train_df.hist(column='auto_35_Y')
auto_train_df.hist(column='auto_36_X')
auto_train_df.hist(column='auto_36_Y')
auto_train_df.hist(column='auto_37_X')
auto_train_df.hist(column='auto_37_Y')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/tools.py:218: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd10aacb50>]],
#       dtype=object)

# %% [markdown]
# **-----------------------BB TEST STATS BELOW------------------------------------------**

# %%
bb_test_df = pd.read_csv('bb_test.txt')

# %%
bb_test_df.head()
# Out:
#      id    bb_1_pt1    bb_1_pt2    bb_1_pt3    bb_1_pt4
# 0  1105  124.799927  124.560852  281.588074  331.495789
# 1  2037  126.194618   96.522148  250.737549  260.799652
# 2     7  315.000885  279.897644  613.883423  685.204834
# 3   233  339.038055  285.997886  701.575053  711.978858
# 4  2203   62.013515   52.464569  123.441795  137.505783

# %%
bb_test_df.describe()
# Out:
#                 id     bb_1_pt1     bb_1_pt2     bb_1_pt3     bb_1_pt4
# count  3068.000000  3068.000000  3068.000000  3068.000000  3068.000000
# mean   1534.500000   151.388471   126.412294   328.627102   356.033716
# std     885.799639   112.914162    93.495189   251.111188   271.082260
# min       1.000000     7.338364    -9.947469    22.853066    23.860465
# 25%     767.750000    59.326945    50.277096   125.990577   137.264503
# 50%    1534.500000   119.469250   100.022782   254.521911   274.226517
# 75%    2301.250000   216.791340   180.482205   469.716179   511.692322
# max    3068.000000   737.545593   630.057983  1570.393066  1777.351318

# %%
bb_test_df.loc[bb_test_df['bb_1_pt2'] <= 0]
# Out:
#         id   bb_1_pt1  bb_1_pt2    bb_1_pt3    bb_1_pt4
# 2926  1838  39.965714 -9.947469  127.610611  100.932426

# %%
bb_test_df.shape
# Out:
# (3068, 5)

# %%
bb_test_df.isnull().values.any()
# Out:
# False

# %%
bb_test_df.hist(column='bb_1_pt1')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd0fef9b10>]],
#       dtype=object)

# %%
bb_test_df.hist(column='bb_1_pt2')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd0fd67bd0>]],
#       dtype=object)

# %%
bb_test_df.hist(column='bb_1_pt3')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd0fce2ad0>]],
#       dtype=object)

# %%
bb_test_df.hist(column='bb_1_pt4')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd0fc7dd10>]],
#       dtype=object)

# %% [markdown]
# **----------------------BB TRAIN STATS BELOW------------------------------------**

# %%
bb_train_df = pd.read_csv('bb_train.txt')

# %%
bb_train_df.head()
# Out:
#      id    bb_1_pt1    bb_1_pt2    bb_1_pt3    bb_1_pt4
# 0   184  156.095856  138.651688  333.541046  360.599304
# 1  5306  175.371368  155.094650  409.957489  497.285309
# 2  9413   71.655945   66.073273  150.246841  172.332062
# 3  2254   95.245071   77.654488  234.916443  252.634750
# 4  7336  353.084567  297.527484  663.545455  682.618393

# %%
bb_train_df.describe()
# Out:
#                  id      bb_1_pt1      bb_1_pt2      bb_1_pt3      bb_1_pt4
# count  12271.000000  12271.000000  12271.000000  12271.000000  12271.000000
# mean    6136.000000    147.616199    122.308204    322.474596    348.723218
# std     3542.476911    110.072397     90.599034    248.960841    267.946163
# min        1.000000     -0.917786    -93.056015     24.151163     25.400634
# 25%     3068.500000     59.988100     50.542029    127.130237    137.967697
# 50%     6136.000000    111.827682     93.373260    241.589233    260.296051
# 75%     9203.500000    210.502159    173.439529    460.858383    498.906494
# max    12271.000000    729.517700    582.126648   1648.765869   1776.807129

# %%
bb_train_df.loc[bb_train_df['bb_1_pt1'] <= 0]
# Out:
#         id  bb_1_pt1    bb_1_pt2    bb_1_pt3    bb_1_pt4
# 11012  613 -0.917786  208.014481  276.283875  593.240295

# %%
bb_train_df.loc[bb_train_df['bb_1_pt2'] <= 0]
# Out:
#           id    bb_1_pt1   bb_1_pt2     bb_1_pt3     bb_1_pt4
# 1684    4655   30.421951 -93.056015   850.218079  1055.463745
# 6994    1987   76.958214  -5.833565   458.888489   458.834412
# 8256    8780  253.515610 -11.648684  1132.029053  1109.717163
# 8548    8621   83.525078  -8.647791   352.009583   408.448059
# 9132    6645  102.671616 -16.882593   177.766495    70.848175
# 10696   5643   25.642321  -6.613603   160.531860   156.602295
# 11732  10621   81.630493 -36.569080   244.112854   199.097504

# %%
bb_train_df.isnull().values.any()
# Out:
# False

# %%
bb_train_df.shape
# Out:
# (12271, 5)

# %%
bb_train_df.hist(column='bb_1_pt1')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd0fc118d0>]],
#       dtype=object)

# %%
bb_train_df.hist(column='bb_1_pt2')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd0fb22a10>]],
#       dtype=object)

# %%
bb_train_df.hist(column='bb_1_pt3')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd0fab3650>]],
#       dtype=object)

# %%
bb_train_df.hist(column='bb_1_pt4')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd0fa2f210>]],
#       dtype=object)

# %% [markdown]
# **---------------------------MANUAL TEST STATS BELOW----------------------**

# %%
manual_test_df = pd.read_csv('filled_manual_test.txt')

# %%
manual_test_df.head()
# Out:
#      id  manual_1_X  manual_1_Y  manual_2_X  manual_2_Y  manual_3_X  \
# 0   461     116.162     124.366     160.162     119.615     140.954
# 1   474      59.336      77.580      77.340      77.100      61.976
# 2  1490     393.955     390.644     554.007     356.426     485.571
# 3  1485     232.192     243.675     318.698     247.503     277.762
# 4  2168      77.511      86.917     110.395      87.072      92.294
#
#    manual_3_Y  manual_4_X  manual_4_Y  manual_5_X  manual_5_Y  Gender  Race  \
# 0     144.167     125.959     168.693     161.416     163.879       0     0
# 1      86.223      64.617     100.146      78.060      99.186       0     0
# 2     454.664     456.872     563.941     573.875     537.450       1     0
# 3     298.992     238.045     326.563     308.365     335.660       1     0
# 4      98.461      79.044     114.776     107.775     115.519       0     0
#
#    Age
# 0    2
# 1    3
# 2    2
# 3    3
# 4    3

# %%
manual_test_df.isnull().values.any()
# Out:
# False

# %%
manual_test_df.isnull().sum()
# Out:
# id            0
# manual_1_X    0
# manual_1_Y    0
# manual_2_X    0
# manual_2_Y    0
# manual_3_X    0
# manual_3_Y    0
# manual_4_X    0
# manual_4_Y    0
# manual_5_X    0
# manual_5_Y    0
# Gender        0
# Race          0
# Age           0
# dtype: int64

# %%
manual_test_df[manual_test_df['manual_5_X'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, manual_1_X, manual_1_Y, manual_2_X, manual_2_Y, manual_3_X, manual_3_Y, manual_4_X, manual_4_Y, manual_5_X, manual_5_Y, Gender, Race, Age]
# Index: []

# %%
manual_test_df[manual_test_df['manual_5_Y'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, manual_1_X, manual_1_Y, manual_2_X, manual_2_Y, manual_3_X, manual_3_Y, manual_4_X, manual_4_Y, manual_5_X, manual_5_Y, Gender, Race, Age]
# Index: []

# %%
manual_test_df[manual_test_df['Gender'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, manual_1_X, manual_1_Y, manual_2_X, manual_2_Y, manual_3_X, manual_3_Y, manual_4_X, manual_4_Y, manual_5_X, manual_5_Y, Gender, Race, Age]
# Index: []

# %%
manual_test_df[manual_test_df['Race'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, manual_1_X, manual_1_Y, manual_2_X, manual_2_Y, manual_3_X, manual_3_Y, manual_4_X, manual_4_Y, manual_5_X, manual_5_Y, Gender, Race, Age]
# Index: []

# %%
manual_test_df[manual_test_df['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, manual_1_X, manual_1_Y, manual_2_X, manual_2_Y, manual_3_X, manual_3_Y, manual_4_X, manual_4_Y, manual_5_X, manual_5_Y, Gender, Race, Age]
# Index: []

# %%
manual_test_df.shape
# Out:
# (3068, 14)

# %%
manual_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3068 entries, 0 to 3067
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          3068 non-null   int64
#  1   manual_1_X  3068 non-null   float64
#  2   manual_1_Y  3068 non-null   float64
#  3   manual_2_X  3068 non-null   float64
#  4   manual_2_Y  3068 non-null   float64
#  5   manual_3_X  3068 non-null   float64
#  6   manual_3_Y  3068 non-null   float64
#  7   manual_4_X  3068 non-null   float64
#  8   manual_4_Y  3068 non-null   float64
#  9   manual_5_X  3068 non-null   float64
#  10  manual_5_Y  3068 non-null   float64
#  11  Gender      3068 non-null   int64
#  12  Race        3068 non-null   int64
#  13  Age         3068 non-null   int64
# dtypes: float64(10), int64(4)
# memory usage: 335.7 KB

# %%
manual_test_df['id'] = manual_test_df['id'].astype(float)

# %%
manual_test_df['manual_1_X'].dtypes
# Out:
# dtype('float64')

# %%
manual_test_df = manual_test_df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
manual_test_df.hist(column='manual_1_X')
manual_test_df.hist(column='manual_1_Y')
manual_test_df.hist(column='manual_2_X')
manual_test_df.hist(column='manual_2_Y')
manual_test_df.hist(column='manual_3_X')
manual_test_df.hist(column='manual_3_Y')
manual_test_df.hist(column='manual_4_X')
manual_test_df.hist(column='manual_4_Y')
manual_test_df.hist(column='manual_5_X')
manual_test_df.hist(column='manual_5_Y')
manual_test_df.hist(column='Gender')
manual_test_df.hist(column='Race')
manual_test_df.hist(column='Age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcd0f50be50>]],
#       dtype=object)

# %% [markdown]
# ------------------------**MANUAL TRAIN STATS BELOW**---------------------------

# %%
manual_train_df = pd.read_csv('filled_manual_train.txt')

# %%
manual_train_df.head()
# Out:
#       id  manual_1_X  manual_1_Y  manual_2_X  manual_2_Y  manual_3_X  \
# 0   3396      49.717      52.668      66.047      53.490      56.588
# 1   4548     263.424     256.442     345.468     230.839     357.105
# 2   3383     153.938     168.343     222.093     173.324     189.314
# 3  11406      48.938      49.313      68.188      53.125      56.813
# 4  11413     347.057     377.877     480.759     377.908     391.157
#
#    manual_3_Y  manual_4_X  manual_4_Y  manual_5_X  manual_5_Y  Gender  Race  \
# 0      63.745      46.746      65.425      66.696      68.856       0     0
# 1     317.538     277.971     379.216     342.558     368.743       1     0
# 2     209.578     152.332     237.299     215.898     239.318       1     0
# 3      65.000      46.188      69.250      63.250      71.813       0     0
# 4     441.117     347.146     526.761     467.286     524.382       0     0
#
#    Age
# 0    2
# 1    2
# 2    3
# 3    2
# 4    3

# %%
manual_train_df.shape
# Out:
# (12271, 14)

# %%
manual_train_df.isnull().sum()
# Out:
# id            0
# manual_1_X    0
# manual_1_Y    0
# manual_2_X    0
# manual_2_Y    0
# manual_3_X    0
# manual_3_Y    0
# manual_4_X    0
# manual_4_Y    0
# manual_5_X    0
# manual_5_Y    0
# Gender        0
# Race          0
# Age           0
# dtype: int64

# %%
manual_train_df[manual_train_df['manual_5_X'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, manual_1_X, manual_1_Y, manual_2_X, manual_2_Y, manual_3_X, manual_3_Y, manual_4_X, manual_4_Y, manual_5_X, manual_5_Y, Gender, Race, Age]
# Index: []

# %%
manual_train_df[manual_train_df['manual_5_Y'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, manual_1_X, manual_1_Y, manual_2_X, manual_2_Y, manual_3_X, manual_3_Y, manual_4_X, manual_4_Y, manual_5_X, manual_5_Y, Gender, Race, Age]
# Index: []

# %%
manual_train_df[manual_train_df['Gender'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, manual_1_X, manual_1_Y, manual_2_X, manual_2_Y, manual_3_X, manual_3_Y, manual_4_X, manual_4_Y, manual_5_X, manual_5_Y, Gender, Race, Age]
# Index: []

# %%
manual_train_df[manual_train_df['Race'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, manual_1_X, manual_1_Y, manual_2_X, manual_2_Y, manual_3_X, manual_3_Y, manual_4_X, manual_4_Y, manual_5_X, manual_5_Y, Gender, Race, Age]
# Index: []

# %%
manual_train_df[manual_train_df['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, manual_1_X, manual_1_Y, manual_2_X, manual_2_Y, manual_3_X, manual_3_Y, manual_4_X, manual_4_Y, manual_5_X, manual_5_Y, Gender, Race, Age]
# Index: []

# %%
manual_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12271 entries, 0 to 12270
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          12271 non-null  int64
#  1   manual_1_X  12271 non-null  float64
#  2   manual_1_Y  12271 non-null  float64
#  3   manual_2_X  12271 non-null  float64
#  4   manual_2_Y  12271 non-null  float64
#  5   manual_3_X  12271 non-null  float64
#  6   manual_3_Y  12271 non-null  float64
#  7   manual_4_X  12271 non-null  float64
#  8   manual_4_Y  12271 non-null  float64
#  9   manual_5_X  12271 non-null  float64
#  10  manual_5_Y  12271 non-null  float64
#  11  Gender      12271 non-null  int64
#  12  Race        12271 non-null  int64
#  13  Age         12271 non-null  int64
# dtypes: float64(10), int64(4)
# memory usage: 1.3 MB
